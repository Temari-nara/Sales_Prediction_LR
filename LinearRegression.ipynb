# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Advertising.csv",index_col = 0)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #Check for Null values

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# #Outlier detection

# %%
plt.boxplot(df["TV"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27ee9f60430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27ee9f609d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27ee9f60160>],
#  'medians': [<matplotlib.lines.Line2D at 0x27ee9f60f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27ee9f6d280>],
#  'means': []}

# %%
plt.boxplot(df["newspaper"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27ee9fbb760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27ee9fbbd00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27ee9fbb490>],
#  'medians': [<matplotlib.lines.Line2D at 0x27ee9fc82e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27ee9fc85b0>],
#  'means': []}

# %%
plt.boxplot(df["radio"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27eea18cac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27eea0190a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27eea18c7c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27eea019640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27eea019910>],
#  'means': []}

# %%
x = df["TV"]
y = df["sales"]

# %%
plt.scatter(x,y)
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("Sales Prediction")
# Out:
# Text(0.5, 1.0, 'Sales Prediction')

# %%
x = df["newspaper"]
y = df["sales"]
plt.scatter(x,y)
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.title("Sales Prediction")
# Out:
# Text(0.5, 1.0, 'Sales Prediction')

# %%
x = df["radio"]
y = df["sales"]
plt.scatter(x,y)
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Sales Prediction")
# Out:
# Text(0.5, 1.0, 'Sales Prediction')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Linear Regression Formula : y = b0 + b1x1

# %%
x = df[["TV","radio","newspaper"]]

# %%
x
# Out:
#         TV  radio  newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df[["sales"]]

# %%
y
# Out:
#      sales
# 1     22.1
# 2     10.4
# 3      9.3
# 4     18.5
# 5     12.9
# ..     ...
# 196    7.6
# 197    9.7
# 198   12.8
# 199   25.5
# 200   13.4
#
# [200 rows x 1 columns]

# %%
print("Shape of x",x.shape)
# Out:
# Shape of x (200, 3)

# %%
print("Shape of y",y.shape)
# Out:
# Shape of y (200, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
print("Shape of s x_train",x_train.shape)
print("Shape of s x_test",x_test.shape)
print("Shape of s y_train",y_train.shape)
print("Shape of s x_test",x_test.shape)
# Out:
# Shape of s x_train (160, 3)
# Shape of s x_test (40, 3)
# Shape of s y_train (160, 1)
# Shape of s x_test (40, 3)

# %%
x_train
# Out:
#         TV  radio  newspaper
# 94   250.9   36.5       72.3
# 31   292.9   28.3       43.2
# 98   184.9   21.0       22.0
# 141   73.4   17.0       12.9
# 93   217.7   33.5       59.0
# ..     ...    ...        ...
# 11    66.1    5.8       24.2
# 87    76.3   27.5       16.0
# 12   214.7   24.0        4.0
# 13    23.8   35.1       65.9
# 154  171.3   39.7       37.7
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  radio  newspaper
# 129  220.3   49.0        3.2
# 86   193.2   18.4       65.7
# 171   50.0   11.6       18.4
# 15   204.1   32.9       46.0
# 136   48.3   47.0        8.5
# 33    97.2    1.5       30.0
# 78   120.5   28.5       14.2
# 114  209.6   20.6       10.7
# 124  123.1   34.6       12.4
# 195  149.7   35.6        6.0
# 37   266.9   43.8        5.0
# 196   38.2    3.7       13.8
# 157   93.9   43.5       50.5
# 75   213.4   24.6       13.1
# 18   281.4   39.6       55.8
# 152  121.0    8.4       48.7
# 103  280.2   10.1       21.4
# 32   112.9   17.4       38.6
# 115   78.2   46.8       34.5
# 146  140.3    1.9        9.0
# 181  156.6    2.6        8.3
# 187  139.5    2.1       26.6
# 30    70.6   16.0       40.8
# 28   240.1   16.7       22.9
# 155  187.8   21.1        9.5
# 97   197.6    3.5        5.9
# 178  170.2    7.8       35.2
# 169  215.4   23.6       57.6
# 73    26.8   33.0       19.3
# 25    62.3   12.6       18.3
# 85   213.5   43.0       33.8
# ...

# %%
y_train
# Out:
#      sales
# 94    22.2
# 31    21.4
# 98    15.5
# 141   10.9
# 93    19.4
# ..     ...
# 11     8.6
# 87    12.0
# 12    17.4
# 13     9.2
# 154   19.0
#
# [160 rows x 1 columns]

# %%
y_test
# Out:
#      sales
# 129   24.7
# 86    15.2
# 171    8.4
# 15    19.0
# 136   11.6
# 33     9.6
# 78    14.2
# 114   15.9
# 124   15.2
# 195   17.3
# 37    25.4
# 196    7.6
# 157   15.3
# 75    17.0
# 18    24.4
# 152   11.6
# 103   14.8
# 32    11.9
# 115   14.6
# 146   10.3
# 181   10.5
# 187   10.3
# 30    10.5
# 28    15.9
# 155   15.6
# 97    11.7
# 178   11.7
# 169   17.1
# 73     8.8
# 25     9.7
# 85    21.7
# 41    16.6
# 189   15.9
# 185   17.6
# 91    11.2
# 128    8.8
# 199   25.5
# 20    14.6
# 176   27.0
# 148   25.4

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model = lm.fit(x_train,y_train)

# %%
print(lm.coef_)
# Out:
# [[ 0.04580331  0.18708722 -0.00179413]]

# %%
print(lm.intercept_)
# Out:
# [2.89548607]

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([[22.1474885 ],
#        [15.06921655],
#        [ 7.32285142],
#        [18.31658173],
#        [13.88563514],
#        [ 7.57437502],
#        [13.72129436],
#        [16.33066011],
#        [14.98484444],
#        [16.40178226],
#        [23.30583997],
#        [ 5.31263632],
#        [15.2441074 ],
#        [17.24875565],
#        [23.09307974],
#        [ 9.92184538],
#        [17.5807611 ],
#        [11.25274423],
#        [15.17108931],
#        [ 9.66100954],
#        [10.53982051],
#        [ 9.63020758],
#        [ 9.04939485],
#        [16.97613262],
#        [15.42784443],
#        [12.5904408 ],
#        [12.08733691],
#        [17.07343612],
#        [10.26226622],
#        [ 8.07349881],
#        [20.65860219],
#        [16.28600746],
#        [18.5891079 ],
#        [18.45150087],
#        [ 9.94691306],
#        [ 6.55240583],
#        [23.62419736],
#        [14.07943074],
#        [24.6519938 ],
#        [23.12264551]])

# %%
new_df = pd.DataFrame()
new_df = x_test
new_df['Actual sales'] = y_test
new_df['Predicted sales'] = y_pred
new_df
# Out:
#         TV  radio  newspaper  Actual sales  Predicted sales
# 129  220.3   49.0        3.2          24.7        22.147488
# 86   193.2   18.4       65.7          15.2        15.069217
# 171   50.0   11.6       18.4           8.4         7.322851
# 15   204.1   32.9       46.0          19.0        18.316582
# 136   48.3   47.0        8.5          11.6        13.885635
# 33    97.2    1.5       30.0           9.6         7.574375
# 78   120.5   28.5       14.2          14.2        13.721294
# 114  209.6   20.6       10.7          15.9        16.330660
# 124  123.1   34.6       12.4          15.2        14.984844
# 195  149.7   35.6        6.0          17.3        16.401782
# 37   266.9   43.8        5.0          25.4        23.305840
# 196   38.2    3.7       13.8           7.6         5.312636
# 157   93.9   43.5       50.5          15.3        15.244107
# 75   213.4   24.6       13.1          17.0        17.248756
# 18   281.4   39.6       55.8          24.4        23.093080
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
r2 = r2_score(y_test,y_pred)
print("R-Squared",r2*100)
# Out:
# R-Squared 92.7458126805344

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE",rmse)
# Out:
# RMSE 1.4280013561098848

# %%
#Conerting the data frame back to CSV
new_df.to_csv("SalesPredicted.csv")
